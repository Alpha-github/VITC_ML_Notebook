# %%
import random
import csv

# %%
headers = ['index','Year','P1','P2','P3','P4']
num = 15

intial_yr_ht1 = (2010,155)
fin_yr_ht1 = (2025,180)

intial_yr_ht2 = (2010,140)
fin_yr_ht2 = (2025,172)

intial_yr_ht3 = (2010,150)
fin_yr_ht3 = (2025,190)

intial_yr_ht4 = (2010,165)
fin_yr_ht4 = (2025,170)

rec=[]

m1 = (fin_yr_ht1[1] - intial_yr_ht1[1])/(fin_yr_ht1[0]-intial_yr_ht1[0])
m2 = (fin_yr_ht2[1] - intial_yr_ht2[1])/(fin_yr_ht2[0]-intial_yr_ht2[0])
m3 = (fin_yr_ht3[1] - intial_yr_ht3[1])/(fin_yr_ht3[0]-intial_yr_ht3[0])
m4 = (fin_yr_ht4[1] - intial_yr_ht4[1])/(fin_yr_ht4[0]-intial_yr_ht4[0])

for i in range(16):
    t = []
    t.extend([i+1,2010+i,m1*(2010+i),m2*(2010+i),m3*(2010+i),m4*(2010+i)])
    rec.append(t)
rec
# Out:
# [[1, 2010, 3350.0, 4288.0, 5360.0, 670.0],
#  [2,
#   2011,
#   3351.666666666667,
#   4290.133333333333,
#   5362.666666666666,
#   670.3333333333333],
#  [3,
#   2012,
#   3353.3333333333335,
#   4292.266666666666,
#   5365.333333333333,
#   670.6666666666666],
#  [4, 2013, 3355.0, 4294.4, 5368.0, 671.0],
#  [5,
#   2014,
#   3356.666666666667,
#   4296.533333333333,
#   5370.666666666666,
#   671.3333333333333],
#  [6,
#   2015,
#   3358.3333333333335,
#   4298.666666666667,
#   5373.333333333333,
#   671.6666666666666],
#  [7, 2016, 3360.0, 4300.8, 5376.0, 672.0],
#  [8,
#   2017,
#   3361.666666666667,
#   4302.933333333333,
#   5378.666666666666,
#   672.3333333333333],
#  [9,
#   2018,
#   3363.3333333333335,
#   4305.066666666667,
#   5381.333333333333,
#   672.6666666666666],
#  [10, 2019, 3365.0, 4307.2, 5384.0, 673.0],
#  [11,
#   2020,
#   3366.666666666667,
#   4309.333333333333,
#   5386.666666666666,
#   673.3333333333333],
#  [12,
#   2021,
#   3368.3333333333335,
# ...
