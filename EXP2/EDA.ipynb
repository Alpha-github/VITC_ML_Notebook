# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk
import numpy as np
import scipy as sp

# %%
df = pd.read_csv("./Marks_data_mod.csv", index_col="index")
df
# Out:
#              Name   Roll no.  OS  DAA  ML Gender  Total    average Grade
# index
# 1      jbdptaqgpo  21CSE1494  33   34  23      F     90  30.000000     F  \
# 2      zmowkfqdqn  21CSE1345  54   92  19      F    165  55.000000     D
# 3      kbncejfdiz  21BRS1173  89   58  62      M    209  69.666667     C
# 4      lrekzbtbzz  21BAI1130  55   45  25      M    125  41.666667     E
# 5      lilkxtrhto  21CSE1531  26   28  19      F     73  24.333333     F
# ...           ...        ...  ..  ...  ..    ...    ...        ...   ...
# 2996   bbcugfurxl  21CSE1038  12   98  18      F    128  42.666667     E
# 2997   haqovhvljx  21CSE1598  74   90   0      M    164  54.666667     D
# 2998   jymmarqeyw  21BAI1192  62   34  90      M    186  62.000000     C
# 2999   djqdivwhbf  21BRS1331  51   27  69      F    147  49.000000     E
# 3000   wynrirsrvy  21CPS1375  63   18  63      F    144  48.000000     E
#
#       Status
# index
# 1          F
# 2          P
# 3          P
# 4          P
# ...

# %%
# print(df.head())
df.tail()
# Out:
#              Name   Roll no.  OS  DAA  ML Gender  Total    average Grade
# index
# 2996   bbcugfurxl  21CSE1038  12   98  18      F    128  42.666667     E  \
# 2997   haqovhvljx  21CSE1598  74   90   0      M    164  54.666667     D
# 2998   jymmarqeyw  21BAI1192  62   34  90      M    186  62.000000     C
# 2999   djqdivwhbf  21BRS1331  51   27  69      F    147  49.000000     E
# 3000   wynrirsrvy  21CPS1375  63   18  63      F    144  48.000000     E
#
#       Status
# index
# 2996       P
# 2997       P
# 2998       P
# 2999       P
# 3000       P

# %%
df.head()
# Out:
#              Name   Roll no.  OS  DAA  ML Gender  Total    average Grade
# index
# 1      jbdptaqgpo  21CSE1494  33   34  23      F     90  30.000000     F  \
# 2      zmowkfqdqn  21CSE1345  54   92  19      F    165  55.000000     D
# 3      kbncejfdiz  21BRS1173  89   58  62      M    209  69.666667     C
# 4      lrekzbtbzz  21BAI1130  55   45  25      M    125  41.666667     E
# 5      lilkxtrhto  21CSE1531  26   28  19      F     73  24.333333     F
#
#       Status
# index
# 1          F
# 2          P
# 3          P
# 4          P
# 5          F

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3000 entries, 1 to 3000
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      3000 non-null   object
#  1   Roll no.  3000 non-null   object
#  2   OS        3000 non-null   int64
#  3   DAA       3000 non-null   int64
#  4   ML        3000 non-null   int64
#  5   Gender    3000 non-null   object
#  6   Total     3000 non-null   int64
#  7   average   3000 non-null   float64
#  8   Grade     3000 non-null   object
#  9   Status    3000 non-null   object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 257.8+ KB

# %%
df.describe()
# Out:
#                 OS          DAA           ML        Total      average
# count  3000.000000  3000.000000  3000.000000  3000.000000  3000.000000
# mean     50.613667    49.803000    50.403000   150.819667    50.273222
# std      29.520166    29.176976    29.163964    50.800296    16.933432
# min       0.000000     0.000000     0.000000     7.000000     2.333333
# 25%      25.000000    25.000000    25.000000   115.000000    38.333333
# 50%      51.000000    50.000000    51.000000   150.000000    50.000000
# 75%      77.000000    75.000000    76.000000   186.000000    62.000000
# max     101.000000   101.000000   101.000000   285.000000    95.000000

# %%
df_group_grade = df.groupby(["Grade"])
print(df_group_grade[['Total',"average"]].mean())
# Out:
#             Total    average
# Grade
# A      254.202128  84.734043
# B      226.155378  75.385126
# C      195.839400  65.279800
# D      167.217886  55.739295
# E      137.855590  45.951863
# F       92.118421  30.706140
# S      277.176471  92.392157

# %%
sns.histplot(df['Total'])
# Out:
# <Axes: xlabel='Total', ylabel='Count'>

# %%
df.hist(figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'OS'}>, <Axes: title={'center': 'DAA'}>],
#        [<Axes: title={'center': 'ML'}>,
#         <Axes: title={'center': 'Total'}>],
#        [<Axes: title={'center': 'average'}>, <Axes: >]], dtype=object)

# %%
sns.catplot(data=df, kind="swarm", x="Gender", y="Total",height=8.27)
plt.title("Gender vs Total Distribution")
# Out:
# Text(0.5, 1.0, 'Gender vs Total Distribution')

# %%
sns.scatterplot(df)
# Out:
# <Axes: xlabel='index'>

# %%
sns.pairplot(df)

# %%
sns.pairplot(data=df, hue="Grade")

# %%
sns.relplot(
    data=df,
    x="Gender", y="average", hue="Status"
)

# %%
sns.kdeplot(df, x = 'average', hue = "Gender", multiple="stack")
plt.title("Distribution of Average marks w.r.t Gender")
# Out:
# Text(0.5, 1.0, 'Distribution of Average marks w.r.t Gender')

# %%
sns.stripplot(data=df, x="Total", y="Grade")
plt.title("Total Marks for Each Grade")
# Out:
# Text(0.5, 1.0, 'Total Marks for Each Grade')
